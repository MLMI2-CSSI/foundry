# %% [markdown]
# # Fashion MNIST
#
# This is a toy example showing how hdf5 files can be used to store image data for a Foundry dataset
#
# More information on the dataset: https://github.com/zalandoresearch/fashion-mnist

# %%
from foundry import Foundry
import matplotlib.pyplot as plt

f = Foundry()
f = f.load("_test_foundry_fashion_mnist_v1.1")
X,y = f.load_data()
X,y = X[0], y[0]  # Select the first item in each returned data list

# %%
n_cols = 6
display_shape = (28,28)
ml_shape = (28,28,1)
fig, ax = plt.subplots(1,n_cols)

for i in range(0, n_cols):
    ax[i].imshow(imgs[i].reshape(fashion_shape), cmap='gray')
