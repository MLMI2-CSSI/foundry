# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MLMI2-CSSI/foundry/blob/main/examples/01_quickstart/quickstart.ipynb)
#
# ---

# %% [markdown]
# # Foundry Quickstart
#
# **Time:** 5 minutes
# **Prerequisites:** Python basics
# **What you'll learn:** Search, load, and use a materials science dataset
#
# ---

# %% [markdown]
# ## Installation
#
# ```bash
# pip install foundry-ml
# ```

# %% [markdown]
# ## 1. Connect to Foundry

# %%
from foundry import Foundry

# Create a Foundry client (uses HTTPS download by default)
# For Google Colab or cloud environments, add: no_browser=True, no_local_server=True
f = Foundry()

# %% [markdown]
# ## 2. Search for Datasets
#
# Search by keyword - you don't need to know exact dataset names.

# %%
# Search for band gap datasets (a key property in materials science)
results = f.search("band gap", limit=5)
results
# Out:
#                    dataset_name  \
# 0  foundry_g4mp2_solvation_v1.2
#
#                                                title       year  \
# 0  DFT Estimates of Solvation Energy in Multiple ...  root=2022
#
#                   DOI                                     FoundryDataset
# 0  10.18126/jos5-wj65  <foundry.foundry_dataset.FoundryDataset object...

# %% [markdown]
# ## 3. Load a Dataset

# %%
# Get the first result
dataset = results.iloc[0].FoundryDataset

# Load the data
data = dataset.get_as_dict()

# Most datasets have train/test splits with (inputs, targets)
print(f"Available splits: {list(data.keys())}")
# Out:
# ---------------------------------------------------------------------------
# TransferAPIError                          Traceback (most recent call last)
# Cell In[3], line 5
#       2 dataset = results.iloc[0].FoundryDataset
#       4 # Load the data
# ----> 5 data = dataset.get_as_dict()
#       7 # Most datasets have train/test splits with (inputs, targets)
#       8 print(f"Available splits: {list(data.keys())}")
#
# File ~/Desktop/git/f-dev/foundry/foundry_dataset.py:75, in FoundryDataset.get_as_dict(self, split, as_hdf5, include_schema)
#      58 def get_as_dict(self, split: str = None, as_hdf5: bool = False, include_schema: bool = False):
#      59     """Returns the data from the dataset as a dictionary
#      60
#      61     Arguments:
#    (...)
#      73
#      74     """
# ---> 75     data = self._foundry_cache.load_as_dict(split,
#      76                                             self.dataset_name,
#      77                                             self.foundry_schema,
#      78                                             as_hdf5)
#      79     if include_schema:
#      80         return {
#      81             "data": data,
#      82             "schema": self.get_schema(),
#      83         }
#
# File ~/Desktop/git/f-dev/foundry/foundry_cache.py:205, in FoundryCache.load_as_dict(self, split, dataset_name, foundry_schema, as_hdf5)
#     192 """
#     193 Load the data associated with the specified dataset and return it as a labeled dictionary of tuples.
#     194
#    (...)
#     202     dict: A labeled dictionary of tuples containing the loaded data.
#     203 """
#     204 # Ensure local copy of data is available
# --> 205 self.download_to_cache(dataset_name,
#     206                        foundry_schema.splits)
#     208 data = {}
#     210 # Handle splits if they exist. Return as a labeled dictionary of tuples
#
# File ~/Desktop/git/f-dev/foundry/foundry_cache.py:75, in FoundryCache.download_to_cache(self, dataset_name, splits)
#      73         self.download_via_globus(dataset_name)
#      74     else:
# ---> 75         self.download_via_http(dataset_name)
#      77 self.validate_local_dataset_storage(dataset_name, splits)
#      79 return self
#
# File ~/Desktop/git/f-dev/foundry/foundry_cache.py:121, in FoundryCache.download_via_http(self, dataset_name)
#     115 task_generator = recursive_ls(self.transfer_client,
#     116                               https_config['source_ep_id'],
#     117                               https_config['folder_to_crawl'])
#     119 with ThreadPoolExecutor(self.parallel_https) as executor:
#     120     # First submit all files
# --> 121     futures = [executor.submit(download_file, f, self.local_cache_dir, https_config)
#     122                for f in tqdm(task_generator, disable=not self.verbose, desc="Finding files")]
#     123     # Check that they completed successfully
#     124     for result in tqdm(as_completed(futures), disable=not self.verbose, desc="Downloading files"):
#
# File /opt/miniconda3/lib/python3.12/site-packages/tqdm/notebook.py:250, in tqdm_notebook.__iter__(self)
#     248 try:
#     249     it = super().__iter__()
# --> 250     for obj in it:
#     251         # return super(tqdm...) will not catch exception
#     252         yield obj
#     253 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File /opt/miniconda3/lib/python3.12/site-packages/tqdm/std.py:1169, in tqdm.__iter__(self)
#    1166 # If the bar is disabled, then just walk the iterable
#    1167 # (note: keep this check outside the loop for performance)
#    1168 if self.disable:
# -> 1169     for obj in iterable:
#    1170         yield obj
#    1171     return
#
# File ~/Desktop/git/f-dev/foundry/https_download.py:32, in recursive_ls(tc, ep, path, max_depth)
#      30 queue = deque()
#      31 queue.append((path, "", 0))
# ---> 32 yield from _get_files(tc, ep, queue, max_depth)
#
# File ~/Desktop/git/f-dev/foundry/https_download.py:40, in _get_files(tc, ep, queue, max_depth)
#      37 abs_path, rel_path, depth = queue.pop()
#      38 path_prefix = rel_path + "/" if rel_path else ""
# ---> 40 res = tc.operation_ls(ep, path=abs_path)
#      42 if depth < max_depth:
#      43     queue.extend(
#      44         (
#      45             res["path"] + item["name"],
#    (...)
#      50         if item["type"] == "dir"
#      51     )
#
# File /opt/miniconda3/lib/python3.12/site-packages/globus_sdk/services/transfer/client.py:1378, in TransferClient.operation_ls(self, endpoint_id, path, show_hidden, orderby, limit, offset, filter, local_user, query_params)
#    1374     query_params["local_user"] = local_user
#    1376 log.debug(f"TransferClient.operation_ls({endpoint_id}, {query_params})")
#    1377 return IterableTransferResponse(
# -> 1378     self.get(f"operation/endpoint/{endpoint_id}/ls", query_params=query_params)
#    1379 )
#
# File /opt/miniconda3/lib/python3.12/site-packages/globus_sdk/client.py:334, in BaseClient.get(self, path, query_params, headers, automatic_authorization)
#     328 """
#     329 Make a GET request to the specified path.
#     330
#     331 See :py:meth:`~.BaseClient.request` for details on the various parameters.
#     332 """
#     333 log.debug(f"GET to {path} with query_params {query_params}")
# --> 334 return self.request(
#     335     "GET",
#     336     path,
#     337     query_params=query_params,
#     338     headers=headers,
#     339     automatic_authorization=automatic_authorization,
#     340 )
#
# File /opt/miniconda3/lib/python3.12/site-packages/globus_sdk/client.py:522, in BaseClient.request(self, method, path, query_params, data, headers, encoding, allow_redirects, stream, automatic_authorization)
#     519     return GlobusHTTPResponse(r, self)
#     521 log.debug(f"request completed with (error) response code: {r.status_code}")
# --> 522 raise self.error_class(r)
#
# TransferAPIError: ('GET', 'https://transfer.api.globus.org/v0.10/operation/endpoint/82f1b5c6-6e9b-11e5-ba47-22000b92c6ec/ls?path=%2Ffoundry%2Ffoundry_g4mp2_solvation_v1.2%2F', 'Bearer', 502, 'ExternalError.DirListingFailed.ConnectFailed', 'Command Failed: Error (connect)\nEndpoint: globuspublish#mdf-publications (82f1b5c6-6e9b-11e5-ba47-22000b92c6ec)\nServer: 141.142.218.119:443\nMessage: Could not connect to server\n---\nDetails: globus_xio: The GSI XIO driver failed to establish a connection via the underlying protocol.\\nglobus_xio: Unable to connect to 141.142.218.119:443\\nglobus_xio: System error in connect: No route to host\\nglobus_xio: A system call failed: No route to host\\n\n', 'R8Vt4ibVW')

# %%
# Extract training data
X_train, y_train = data['train']

print(f"Input features: {type(X_train)}")
print(f"Targets: {type(y_train)}")

# %% [markdown]
# ## 4. Use the Data
#
# Foundry data works with any ML framework.

# %%
# Example: Simple sklearn model
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
import pandas as pd

# Convert to arrays if needed
if isinstance(X_train, dict):
    X_train_df = pd.DataFrame(X_train)
    y_train_arr = list(y_train.values())[0]  # Get first target
else:
    X_train_df = X_train
    y_train_arr = y_train

print(f"Training samples: {len(X_train_df)}")
print(f"Features: {X_train_df.shape[1] if hasattr(X_train_df, 'shape') else 'N/A'}")

# %% [markdown]
# ## 5. Get Citation
#
# Always cite datasets you use in publications!

# %%
citation = dataset.get_citation()
print(citation)

# %% [markdown]
# ## Summary
#
# ```python
# from foundry import Foundry
#
# f = Foundry()  # HTTPS download by default
# results = f.search("band gap")
# dataset = results.iloc[0].FoundryDataset
# X, y = dataset.get_as_dict()['train']
# ```
#
# **Next:** See `02_working_with_data.ipynb` for advanced data handling.
