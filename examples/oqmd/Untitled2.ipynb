# %%
from mdf_forge.forge import Forge
# You don't have to use the name "mdf" but we do for consistency.
mdf = Forge("mdf-test")
mdf.match_field("dc.publisher", "PFHub")
rslt= mdf.search()
for r in rslt:
    print(r)
# Out:
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_spinodal_b_v2.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_spinodal_b_v2.1/'}, 'dc': {'creators': [{'creatorName': 'M, Shubhajit', 'familyName': 'M', 'givenName': 'Shubhajit'}], 'descriptions': [{'description': 'Spinodal decomposition problem for square shape domain with no-flux boundary condition has been solved using open-source finite element software FeniCS.', 'descriptionType': 'Other'}], 'publicationYear': '2019', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'Spinodal_b'}]}, 'mdf': {'ingest_date': '2020-01-17T15:47:00.537598Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_spinodal_b_v2.1', 'source_name': '_test_spinodal_b', 'version': 2}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_mmsp_1b_travis_v2.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_mmsp_1b_travis_v2.1/'}, 'dc': {'creators': [{'creatorName': 'Keller, Trevor', 'familyName': 'Keller', 'givenName': 'Trevor'}], 'descriptions': [{'description': 'Parallel Travis CI benchmark with MMSP, no-flux domain', 'descriptionType': 'Other'}], 'publicationYear': '2017', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'mmsp_1b_travis'}]}, 'mdf': {'ingest_date': '2020-01-17T15:47:01.086032Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_mmsp_1b_travis_v2.1', 'source_name': '_test_mmsp_1b_travis', 'version': 2}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_finite_diff_b_v2.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_finite_diff_b_v2.1/'}, 'dc': {'creators': [{'creatorName': 'Pusztai, Tamás', 'familyName': 'Pusztai', 'givenName': 'Tamás'}], 'descriptions': [{'description': "The three sets of results I submitted (methods A, B, C) are based on finite difference simulations (dx=0.4, dt=0.02) that differ only in the way the anisotropy part of the phi equation of motion calculated. In method A and B, I used the standard discretisation of the divergence part, for which the values of a(theta) and a'(theta) are required at the midpoints between cell points. In method B, these were calculated based on the theta values calculated at the midpoint, e.g.  a(x+dx/2) = a(theta(x+dx/2)).", 'descriptionType': 'Other'}], 'publicationYear': '2018', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'Finite_Diff_B'}]}, 'mdf': {'ingest_date': '2020-01-17T15:47:45.922173Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_finite_diff_b_v2.1', 'source_name': '_test_finite_diff_b', 'version': 2}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_chimad3_moose_v2.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_chimad3_moose_v2.1/'}, 'dc': {'creators': [{'creatorName': 'Kim, Dong-Uk', 'familyName': 'Kim', 'givenName': 'Dong-Uk'}], 'descriptions': [{'description': 'MOOSE framework; mesh adaptivity, bdf2 time stepping with adaptive time steps (dtmax = 0.3), postprocesses on the every timestep', 'descriptionType': 'Other'}], 'publicationYear': '2018', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'CHiMaD3_MOOSE'}]}, 'mdf': {'ingest_date': '2020-01-17T15:47:46.852943Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_chimad3_moose_v2.1', 'source_name': '_test_chimad3_moose', 'version': 2}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_mmsp_1a_raspi_v2.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_mmsp_1a_raspi_v2.1/'}, 'dc': {'creators': [{'creatorName': 'Keller, Trevor', 'familyName': 'Keller', 'givenName': 'Trevor'}], 'descriptions': [{'description': 'Raspberry Pi 3 cluster benchmark with MMSP, periodic domain', 'descriptionType': 'Other'}], 'publicationYear': '2017', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'mmsp_1a_raspi'}]}, 'mdf': {'ingest_date': '2020-01-17T15:47:43.490872Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_mmsp_1a_raspi_v2.1', 'source_name': '_test_mmsp_1a_raspi', 'version': 2}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_moose_1b_ia_v2.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_moose_1b_ia_v2.1/'}, 'dc': {'creators': [{'creatorName': 'Jokisaari, A. M.', 'familyName': 'Jokisaari', 'givenName': 'A. M.'}], 'descriptions': [{'description': 'Information for the Benchmark1 problems', 'descriptionType': 'Other'}], 'publicationYear': '2016', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'moose_1b_ia'}]}, 'mdf': {'ingest_date': '2020-01-17T15:47:42.628922Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_moose_1b_ia_v2.1', 'source_name': '_test_moose_1b_ia', 'version': 2}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_moose_2b_ia_v2.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_moose_2b_ia_v2.1/'}, 'dc': {'creators': [{'creatorName': 'Jokisaari, A. M.', 'familyName': 'Jokisaari', 'givenName': 'A. M.'}], 'descriptions': [{'description': 'Metadata for the Benchmark2 problems', 'descriptionType': 'Other'}], 'publicationYear': '2016', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'moose_2b_ia'}]}, 'mdf': {'ingest_date': '2020-01-17T15:47:48.126741Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_moose_2b_ia_v2.1', 'source_name': '_test_moose_2b_ia', 'version': 2}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_moose_1d_jah_v2.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_moose_1d_jah_v2.1/'}, 'dc': {'creators': [{'creatorName': 'Hirschhorn, Jacob', 'familyName': 'Hirschhorn', 'givenName': 'Jacob'}], 'descriptions': [{'description': 'moose_1d_jah', 'descriptionType': 'Other'}], 'publicationYear': '2018', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'moose_1d_jah'}]}, 'mdf': {'ingest_date': '2020-01-17T15:47:44.370539Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_moose_1d_jah_v2.1', 'source_name': '_test_moose_1d_jah', 'version': 2}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_spinodal_c_v2.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_spinodal_c_v2.1/'}, 'dc': {'creators': [{'creatorName': 'Mondal, Shubhajit', 'familyName': 'Mondal', 'givenName': 'Shubhajit'}], 'descriptions': [{'description': 'Spinodal decomposition problem for T-shape domain has been solved using open-source finite element software FeniCS.', 'descriptionType': 'Other'}], 'publicationYear': '2019', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'Spinodal_c'}]}, 'mdf': {'ingest_date': '2020-01-17T15:48:30.003303Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_spinodal_c_v2.1', 'source_name': '_test_spinodal_c', 'version': 2}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_sfepy_4g_wd15_fake_v2.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_sfepy_4g_wd15_fake_v2.1/'}, 'dc': {'creators': [{'creatorName': 'Wheeler, Daniel', 'familyName': 'Wheeler', 'givenName': 'Daniel'}], 'descriptions': [{'description': 'Fake data to force display of comparision pages', 'descriptionType': 'Other'}], 'publicationYear': '2018', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'sfepy_4g_wd15_fake'}]}, 'mdf': {'ingest_date': '2020-01-17T15:48:30.981995Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_sfepy_4g_wd15_fake_v2.1', 'source_name': '_test_sfepy_4g_wd15_fake', 'version': 2}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_moose_itg_2a_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_moose_itg_2a_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Greenquist, Ian', 'familyName': 'Greenquist', 'givenName': 'Ian'}], 'descriptions': [{'description': 'Results for benchmark 2a', 'descriptionType': 'Other'}], 'publicationYear': '2018', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'moose_itg_2a'}]}, 'mdf': {'ingest_date': '2020-01-17T15:48:32.112037Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_moose_itg_2a_v1.1', 'source_name': '_test_moose_itg_2a', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_finite_diff_c_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_finite_diff_c_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Pusztai, Tamás', 'familyName': 'Pusztai', 'givenName': 'Tamás'}], 'descriptions': [{'description': 'The three sets of results I submitted (methods A, B, C) are based on finite difference simulations (dx=0.4, dt=0.002) that differ only in the way the anisotropy part of the phi equation of motion calculated. In method C, using the chain rule, I calculated all derivatives analytically up to the point where only the derivatives of phi is left and all the other quantities can be evaluated locally.', 'descriptionType': 'Other'}], 'publicationYear': '2018', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'Finite_Diff_C'}]}, 'mdf': {'ingest_date': '2020-01-17T15:48:36.866371Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_finite_diff_c_v1.1', 'source_name': '_test_finite_diff_c', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_prismspf_linear_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_prismspf_linear_v1.1/'}, 'dc': {'creators': [{'creatorName': 'DeWitt, Stephen', 'familyName': 'DeWitt', 'givenName': 'Stephen'}], 'descriptions': [{'description': 'Initial run of Benchmark 7 using PRISMS-PF. This simulation uses linear elements (2nd order accurate in space) and forward Euler time stepping (1st order in time).', 'descriptionType': 'Other'}], 'publicationYear': '2018', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'PRISMSPF_Linear'}]}, 'mdf': {'ingest_date': '2020-01-17T15:48:39.121484Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_prismspf_linear_v1.1', 'source_name': '_test_prismspf_linear', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_mmsp_1c_raspi_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_mmsp_1c_raspi_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Keller, Trevor', 'familyName': 'Keller', 'givenName': 'Trevor'}], 'descriptions': [{'description': 'Raspberry Pi 3 cluster benchmark with MMSP, T-shape domain', 'descriptionType': 'Other'}], 'publicationYear': '2017', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'mmsp_1c_raspi'}]}, 'mdf': {'ingest_date': '2020-01-17T15:48:33.392104Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_mmsp_1c_raspi_v1.1', 'source_name': '_test_mmsp_1c_raspi', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_fipy_1c_travis_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_fipy_1c_travis_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Keller, Trevor', 'familyName': 'Keller', 'givenName': 'Trevor'}], 'descriptions': [{'description': 'Serial Travis CI benchmark with FiPy, T-shape domain', 'descriptionType': 'Other'}], 'publicationYear': '2017', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'fipy_1c_travis'}]}, 'mdf': {'ingest_date': '2020-01-17T15:48:37.831296Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_fipy_1c_travis_v1.1', 'source_name': '_test_fipy_1c_travis', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_fenics_2c_ivan_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_fenics_2c_ivan_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Yashchuk, Ivan', 'familyName': 'Yashchuk', 'givenName': 'Ivan'}], 'descriptions': [{'description': 'PF Hub benchmark 2c with FEniCS on the cluster.', 'descriptionType': 'Other'}], 'publicationYear': '2018', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'fenics_2c_ivan'}]}, 'mdf': {'ingest_date': '2020-01-17T15:48:35.627101Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_fenics_2c_ivan_v1.1', 'source_name': '_test_fenics_2c_ivan', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_prismspf_6b_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_prismspf_6b_v1.1/'}, 'dc': {'creators': [{'creatorName': 'DeWitt, Stephen', 'familyName': 'DeWitt', 'givenName': 'Stephen'}], 'descriptions': [{'description': 'Results data for problem 2b using PRISMS-PF v2.0pre and the Flux cluster at the University of Michigan', 'descriptionType': 'Other'}], 'publicationYear': '2017', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'prismspf_6b'}]}, 'mdf': {'ingest_date': '2020-01-17T15:49:31.586823Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_prismspf_6b_v1.1', 'source_name': '_test_prismspf_6b', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_forward_backward_euler_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_forward_backward_euler_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Sereewattanawoot, Narut', 'familyName': 'Sereewattanawoot', 'givenName': 'Narut'}], 'descriptions': [{'description': "Spatial and temporal convergence data for my serial version with first-order in time, second-order in space Euler method. I treat non-linear terms explicitly, but linear terms implicitly in order to measure time convergence. (Spatial error will dominate with purely explicit Euler everywhere it's stable.) Will parallelize for the later parts of this problem.", 'descriptionType': 'Other'}], 'publicationYear': '2018', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'Forward_Backward_Euler'}]}, 'mdf': {'ingest_date': '2020-01-17T15:49:27.982264Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_forward_backward_euler_v1.1', 'source_name': '_test_forward_backward_euler', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_inl_moose_1b_raspi_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_inl_moose_1b_raspi_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Schwen, Daniel', 'familyName': 'Schwen', 'givenName': 'Daniel'}], 'descriptions': [{'description': 'Raspberry Pi 3 benchmark with MOOSE, no-flux domain', 'descriptionType': 'Other'}], 'publicationYear': '2017', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'inl_moose_1b_raspi'}]}, 'mdf': {'ingest_date': '2020-01-17T15:49:21.778245Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_inl_moose_1b_raspi_v1.1', 'source_name': '_test_inl_moose_1b_raspi', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_hiperc_1b_cuda_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_hiperc_1b_cuda_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Keller, Trevor', 'familyName': 'Keller', 'givenName': 'Trevor'}], 'descriptions': [{'description': 'HiPerC spinodal decomposition result using CUDA on a Tesla P100', 'descriptionType': 'Other'}], 'publicationYear': '2017', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'hiperc_1b_cuda'}]}, 'mdf': {'ingest_date': '2020-01-17T15:50:26.190305Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_hiperc_1b_cuda_v1.1', 'source_name': '_test_hiperc_1b_cuda', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_fipy_1a_travis_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_fipy_1a_travis_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Keller, Trevor', 'familyName': 'Keller', 'givenName': 'Trevor'}], 'descriptions': [{'description': 'Serial Travis CI benchmark with FiPy, periodic domain', 'descriptionType': 'Other'}], 'publicationYear': '2017', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'fipy_1a_travis'}]}, 'mdf': {'ingest_date': '2020-01-17T15:49:31.182329Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_fipy_1a_travis_v1.1', 'source_name': '_test_fipy_1a_travis', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_fenics_2b_ivan_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_fenics_2b_ivan_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Yashchuk, Ivan', 'familyName': 'Yashchuk', 'givenName': 'Ivan'}], 'descriptions': [{'description': 'PF Hub benchmark 2b with FEniCS on the cluster.', 'descriptionType': 'Other'}], 'publicationYear': '2018', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'fenics_2b_ivan'}]}, 'mdf': {'ingest_date': '2020-01-17T15:49:24.382257Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_fenics_2b_ivan_v1.1', 'source_name': '_test_fenics_2b_ivan', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_moose_2d_sta_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_moose_2d_sta_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Jokisaari, A. M.', 'familyName': 'Jokisaari', 'givenName': 'A. M.'}], 'descriptions': [{'description': 'Metadata for the Benchmark2 problems', 'descriptionType': 'Other'}], 'publicationYear': '2016', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'moose_2d_sta'}]}, 'mdf': {'ingest_date': '2020-01-17T15:50:32.642819Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_moose_2d_sta_v1.1', 'source_name': '_test_moose_2d_sta', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_moose_2c_ia_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_moose_2c_ia_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Jokisaari, A. M.', 'familyName': 'Jokisaari', 'givenName': 'A. M.'}], 'descriptions': [{'description': 'Metadata for the Benchmark2 problems', 'descriptionType': 'Other'}], 'publicationYear': '2016', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'moose_2c_ia'}]}, 'mdf': {'ingest_date': '2020-01-17T15:49:23.542251Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_moose_2c_ia_v1.1', 'source_name': '_test_moose_2c_ia', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_itg_moose_1b_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_itg_moose_1b_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Greenquist, Ian', 'familyName': 'Greenquist', 'givenName': 'Ian'}], 'descriptions': [{'description': 'Benchmark Problem 1b', 'descriptionType': 'Other'}], 'publicationYear': '2018', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'itg_moose_1b'}]}, 'mdf': {'ingest_date': '2020-01-17T15:49:20.475100Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_itg_moose_1b_v1.1', 'source_name': '_test_itg_moose_1b', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_moose_1b_jah_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_moose_1b_jah_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Hirschhorn, Jacob', 'familyName': 'Hirschhorn', 'givenName': 'Jacob'}], 'descriptions': [{'description': 'moose_1b_jah', 'descriptionType': 'Other'}], 'publicationYear': '2018', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'moose_1b_jah'}]}, 'mdf': {'ingest_date': '2020-01-17T15:49:25.825467Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_moose_1b_jah_v1.1', 'source_name': '_test_moose_1b_jah', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_example_v1.2/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_example_v1.2/'}, 'dc': {'creators': [{'creatorName': 'Keller, Trevor', 'familyName': 'Keller', 'givenName': 'Trevor'}], 'descriptions': [{'description': 'MPI parallel workstation benchmark with MMSP', 'descriptionType': 'Other'}], 'publicationYear': '2016', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'example'}]}, 'mdf': {'ingest_date': '2020-01-17T15:56:36.792201Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_example_v1.2', 'source_name': '_test_example', 'version': 1}, 'services': {}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_inl_moose_6a_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_inl_moose_6a_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Aagesen, Larry', 'familyName': 'Aagesen', 'givenName': 'Larry'}], 'descriptions': [{'description': 'Benchmark problem 6a, energy vs time. 160 x 160 uniform mesh, iteration adaptive time stepping, target iterations=8', 'descriptionType': 'Other'}], 'publicationYear': '2017', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'inl_moose_6a'}]}, 'mdf': {'ingest_date': '2020-01-17T15:51:30.947450Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_inl_moose_6a_v1.1', 'source_name': '_test_inl_moose_6a', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_mmsp_1b_raspi_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_mmsp_1b_raspi_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Keller, Trevor', 'familyName': 'Keller', 'givenName': 'Trevor'}], 'descriptions': [{'description': 'Raspberry Pi 3 cluster benchmark with MMSP, no-flux domain', 'descriptionType': 'Other'}], 'publicationYear': '2017', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'mmsp_1b_raspi'}]}, 'mdf': {'ingest_date': '2020-01-17T15:51:35.483010Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_mmsp_1b_raspi_v1.1', 'source_name': '_test_mmsp_1b_raspi', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_fenics_1d_ivan_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_fenics_1d_ivan_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Yashchuk, Ivan', 'familyName': 'Yashchuk', 'givenName': 'Ivan'}], 'descriptions': [{'description': 'PF Hub benchmark 1d with FEniCS on the cluster.', 'descriptionType': 'Other'}], 'publicationYear': '2018', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'fenics_1d_ivan'}]}, 'mdf': {'ingest_date': '2020-01-17T15:50:26.821545Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_fenics_1d_ivan_v1.1', 'source_name': '_test_fenics_1d_ivan', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_moose_psu_1d_sta_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_moose_psu_1d_sta_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Simon, PC.', 'familyName': 'Simon', 'givenName': 'PC.'}], 'descriptions': [{'description': 'Metadata for the Benchmark1 problems', 'descriptionType': 'Other'}], 'publicationYear': '2017', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'moose_psu_1d_STA'}]}, 'mdf': {'ingest_date': '2020-01-17T15:50:35.230292Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_moose_psu_1d_sta_v1.1', 'source_name': '_test_moose_psu_1d_sta', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_moose_1c_ia_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_moose_1c_ia_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Jokisaari, A. M.', 'familyName': 'Jokisaari', 'givenName': 'A. M.'}], 'descriptions': [{'description': 'Information for the Benchmark1 problems', 'descriptionType': 'Other'}], 'publicationYear': '2016', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'moose_1c_ia'}]}, 'mdf': {'ingest_date': '2020-01-17T15:50:22.029759Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_moose_1c_ia_v1.1', 'source_name': '_test_moose_1c_ia', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_prismspf_1b_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_prismspf_1b_v1.1/'}, 'dc': {'creators': [{'creatorName': 'DeWitt, Stephen', 'familyName': 'DeWitt', 'givenName': 'Stephen'}], 'descriptions': [{'description': 'Flux cluster benchmark with PRISMS-PF', 'descriptionType': 'Other'}], 'publicationYear': '2017', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'prismspf_1b'}]}, 'mdf': {'ingest_date': '2020-01-17T15:51:34.753102Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_prismspf_1b_v1.1', 'source_name': '_test_prismspf_1b', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_moose_1c_jah_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_moose_1c_jah_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Hirschhorn, Jacob', 'familyName': 'Hirschhorn', 'givenName': 'Jacob'}], 'descriptions': [{'description': 'moose_1c_jah', 'descriptionType': 'Other'}], 'publicationYear': '2018', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'moose_1c_jah'}]}, 'mdf': {'ingest_date': '2020-01-17T15:49:27.639869Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_moose_1c_jah_v1.1', 'source_name': '_test_moose_1c_jah', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_moose_1a_jah_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_moose_1a_jah_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Hirschhorn, Jacob', 'familyName': 'Hirschhorn', 'givenName': 'Jacob'}], 'descriptions': [{'description': 'moose_1a_jah', 'descriptionType': 'Other'}], 'publicationYear': '2018', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'moose_1a_jah'}]}, 'mdf': {'ingest_date': '2020-01-17T15:50:29.926251Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_moose_1a_jah_v1.1', 'source_name': '_test_moose_1a_jah', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_moose_psu_1c_ia_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_moose_psu_1c_ia_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Simon, PC.', 'familyName': 'Simon', 'givenName': 'PC.'}], 'descriptions': [{'description': 'Metadata for the Benchmark1 problems', 'descriptionType': 'Other'}], 'publicationYear': '2017', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'moose_psu_1c_IA'}]}, 'mdf': {'ingest_date': '2020-01-17T15:51:38.306229Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_moose_psu_1c_ia_v1.1', 'source_name': '_test_moose_psu_1c_ia', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_fipy_6b_macbookpro_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_fipy_6b_macbookpro_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Guyer, Jon', 'familyName': 'Guyer', 'givenName': 'Jon'}], 'descriptions': [{'description': 'Serial benchmark with FiPy on Gmsh mesh with round right', 'descriptionType': 'Other'}], 'publicationYear': '2017', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'fipy_6b_macbookpro'}]}, 'mdf': {'ingest_date': '2020-01-17T15:51:41.378256Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_fipy_6b_macbookpro_v1.1', 'source_name': '_test_fipy_6b_macbookpro', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_sfepy_4f_wd15_fake_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_sfepy_4f_wd15_fake_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Wheeler, Daniel', 'familyName': 'Wheeler', 'givenName': 'Daniel'}], 'descriptions': [{'description': 'Fake data to force display of comparision pages', 'descriptionType': 'Other'}], 'publicationYear': '2018', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'sfepy_4f_wd15_fake'}]}, 'mdf': {'ingest_date': '2020-01-17T15:51:44.122379Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_sfepy_4f_wd15_fake_v1.1', 'source_name': '_test_sfepy_4f_wd15_fake', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}
# {'data': {'endpoint_path': 'globus://e38ee745-6d04-11e5-ba46-22000b92c6ec/MDF/mdf_connect/prod/data/_test_fenics_1c_ivan_v1.1/', 'link': 'https://app.globus.org/file-manager?origin_id=e38ee745-6d04-11e5-ba46-22000b92c6ec&origin_path=/MDF/mdf_connect/prod/data/_test_fenics_1c_ivan_v1.1/'}, 'dc': {'creators': [{'creatorName': 'Yashchuk, Ivan', 'familyName': 'Yashchuk', 'givenName': 'Ivan'}], 'descriptions': [{'description': 'PF Hub benchmark 1c with FEniCS on the cluster.', 'descriptionType': 'Other'}], 'publicationYear': '2018', 'publisher': 'PFHub', 'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'}, 'titles': [{'title': 'fenics_1c_ivan'}]}, 'mdf': {'ingest_date': '2020-01-17T15:51:40.733895Z', 'resource_type': 'dataset', 'scroll_id': 0, 'source_id': '_test_fenics_1c_ivan_v1.1', 'source_name': '_test_fenics_1c_ivan', 'version': 1}, 'services': {'mdf_search': 'This dataset was ingested to MDF Search.'}}

# %%
X.sample(10)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 103                6.3               2.9                5.6               1.8
# 96                 5.7               2.9                4.2               1.3
# 25                 5.0               3.0                1.6               0.2
# 63                 6.1               2.9                4.7               1.4
# 109                7.2               3.6                6.1               2.5
# 138                6.0               3.0                4.8               1.8
# 48                 5.3               3.7                1.5               0.2
# 122                7.7               2.8                6.7               2.0
# 4                  5.0               3.6                1.4               0.2
# 88                 5.6               3.0                4.1               1.3
