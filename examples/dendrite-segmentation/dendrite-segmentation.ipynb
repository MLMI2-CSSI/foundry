# %%
from foundry import Foundry
from skimage.io import imshow, imread
from keras_unet.models import custom_unet
import matplotlib.pyplot as plt
from keras_unet.utils import plot_imgs
import numpy as np
import cv2
import numpy as np
import tensorflow as tf
from keras.optimizers import Adam, SGD
from keras_unet.metrics import iou, iou_thresholded
from keras_unet.losses import jaccard_distance

# %%
#need Globus to pull data
f = Foundry(search_index="mdf-test")
f = f.load('_test_foundry_stan_dendrite_segmentation_v1.1')
X,y = f.load_data()
X,y = X[0], y[0]

# %%
fig, axs = plt.subplots(3,2, figsize=(8,8))
for i in range(3):
    axs[i][0].imshow(X[i])
    axs[i][1].imshow(y[i])

# %% [markdown]
# # Build a Model to Predict

# %% [markdown]
# # Resize to Match UNet
# UNet requires images to be of a size multiple of 32

# %%
new_size = 32*10 # U-Net requires a multiple of 32

X_r = np.array([cv2.resize(img, dsize=(new_size, new_size)) 
     for img in X])
y_r = np.array([cv2.resize(mask, dsize=(new_size, new_size)) 
     for mask in y])

# %%
y_r.shape
# Out:
# (30, 320, 320, 3)

# %% [markdown]
# # Create UNet Model

# %%
input_shape = (new_size,new_size,3)

model = custom_unet(input_shape)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 320, 320, 3) 0
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 320, 320, 16) 432         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 320, 320, 16) 64          conv2d_38[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_10 (SpatialDr (None, 320, 320, 16) 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 320, 320, 16) 2304        spatial_dropout2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 320, 320, 16) 64          conv2d_39[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 160, 160, 16) 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 160, 160, 32) 4608        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 160, 160, 32) 128         conv2d_40[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_11 (SpatialDr (None, 160, 160, 32) 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 160, 160, 32) 9216        spatial_dropout2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 160, 160, 32) 128         conv2d_41[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 80, 80, 32)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 80, 80, 64)   18432       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 80, 80, 64)   256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_12 (SpatialDr (None, 80, 80, 64)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 80, 80, 64)   36864       spatial_dropout2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 80, 80, 64)   256         conv2d_43[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 40, 40, 64)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 40, 40, 128)  73728       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 40, 40, 128)  512         conv2d_44[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_13 (SpatialDr (None, 40, 40, 128)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 40, 40, 128)  147456      spatial_dropout2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 40, 40, 128)  512         conv2d_45[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 20, 20, 128)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 20, 20, 256)  294912      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 20, 20, 256)  1024        conv2d_46[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_14 (SpatialDr (None, 20, 20, 256)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 20, 20, 256)  589824      spatial_dropout2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 20, 20, 256)  1024        conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 40, 40, 128)  131200      batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 40, 40, 256)  0           conv2d_transpose_8[0][0]
#                                                                  batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 40, 40, 128)  294912      concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 40, 40, 128)  512         conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 40, 40, 128)  147456      batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 40, 40, 128)  512         conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 80, 80, 64)   32832       batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 80, 80, 128)  0           conv2d_transpose_9[0][0]
#                                                                  batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 80, 80, 64)   73728       concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 80, 80, 64)   256         conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 80, 80, 64)   36864       batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 80, 80, 64)   256         conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 160, 160, 32) 8224        batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 160, 160, 64) 0           conv2d_transpose_10[0][0]
#                                                                  batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 160, 160, 32) 18432       concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 160, 160, 32) 128         conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 160, 160, 32) 9216        batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 160, 160, 32) 128         conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 320, 320, 16) 2064        batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 320, 320, 32) 0           conv2d_transpose_11[0][0]
#                                                                  batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 320, 320, 16) 4608        concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 320, 320, 16) 64          conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 320, 320, 16) 2304        batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 320, 320, 16) 64          conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 320, 320, 1)  17          batch_normalization_53[0][0]
# ==================================================================================================
# Total params: 1,945,521
# Trainable params: 1,942,577
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %% [markdown]
# # Preview the Segmentation Task

# %%
plot_imgs(org_imgs=X_r, mask_imgs=y_r[:,:,:,0], nm_img_to_plot=3, figsize=6)

# %% [markdown]
# # Create a Generator with Augmented Images

# %%
X_r.shape
# Out:
# (30, 320, 320, 3)

# %%
y_r.shape
# Out:
# (30, 320, 320, 3)

# %%
n_images = 30
y_c = y_r[:,:,:,0]

train_gen = get_augmented(
    X_r, np.reshape(y_c, (n_images, new_size, new_size, 1)), batch_size=2,
    data_gen_args = dict(
        rotation_range=5.,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=30,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='constant'
    ))

# %% [markdown]
# # Preview Augmented Images

# %%
sample_batch = next(train_gen)
xx, yy = sample_batch
print(xx.shape, yy.shape)
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=xx, mask_imgs=yy[:,:,:,0], nm_img_to_plot=2, figsize=6)
# Out:
# (2, 320, 320, 3) (2, 320, 320, 1)

# %% [markdown]
# # Compile Model

# %%
model.compile(
    optimizer="adam", 
    #optimizer=SGD(lr=0.01, momentum=0.99),
    loss='binary_crossentropy',
    #loss=jaccard_distance,
    metrics=[tf.keras.metrics.MeanIoU(num_classes=2)]
)

# %% [markdown]
# # Fit Model

# %%
history = model.fit(
train_gen,
    steps_per_epoch=200,
    epochs=10
)
# Out:
# Epoch 1/2
# 200/200 [==============================] - 214s 1s/step - loss: 0.0160 - mean_io_u_2: 0.5600
# Epoch 2/2
# 200/200 [==============================] - 224s 1s/step - loss: 0.0179 - mean_io_u_2: 0.5725

# %%
model.save(f"./{new_size}x{new_size}-model.h5")

# %%
#model = tf.keras.models.load_model('./model_checkpoint.h5')

# %% [markdown]
# # Run Predict on Images

# %%
y_pred = model.predict(X_r)

# %% [markdown]
# # Check Performance Visually

# %%
plot_imgs(org_imgs=X_r, mask_imgs=y_rc, pred_imgs=y_pred, nm_img_to_plot=10)

# %%
metadata = {
    "dc": {
        'creators': [
            {'creatorName': 'Stan, Tiberiu',
             'familyName': 'Stan',
             'givenName': 'Tiberiu'},
            {'creatorName': 'Thompson, Zach',
             'familyName': 'Thompson',
             'givenName': 'Zach'},
            {'creatorName': 'Voorhees, Peter',
             'familyName': 'Voorhees',
             'givenName': 'Peter'}
        ],
        'dates': [{'date': '2020-06-04', 'dateType': 'Accepted'}],
        'identifier': {'identifier': '10.23677/xrmb-v1rz', 'identifierType': 'DOI'},
        'publicationYear': 2020,
        'publisher': 'Materials Data Facility',
        'resourceType': {'resourceType': 'Dataset', 'resourceTypeGeneral': 'Dataset'},
        'subjects': [
            {'subject': 'machine learning'},
            {'subject': 'segmentation'},
            {'subject': 'metals and alloys'},
            {'subject': 'X-ray tomography'},
            {'subject': 'foundry'}
        ],
        'titles': [{'title': 'Semantic Segmentation of Dendrites via Machine Learning'}]
    },
    "mdf": {"source_id":"_test_foundry_stan_dendrite_segmentation_v1.1"},
    "dataset":{"inputs": ["train/input"],
    "outputs": ["train/output"],
    "input_descriptions": [],
    "output_descriptions": [],
    "type": "hdf5",
    "version": "",
    "short_name": "stan-dendrite-segmentation"
    }
}

# %%
import json
with open('foundry_metadata.json', 'w') as f:
    json.dump(metadata, f)
